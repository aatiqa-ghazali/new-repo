# %% [markdown]
# <a href="https://colab.research.google.com/github/aatiqa-ghazali/new-repo/blob/master/new.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# %cd drive/My\ Drive/Colab\ Notebooks/
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/Colab Notebooks

# %%
#%env PYTHONPATH=
# %%bash
MINICONDA_INSTALLER_SCRIPT=Miniconda3-4.5.4-Linux-x86_64.sh
MINICONDA_PREFIX=/usr/local
wget https://repo.continuum.io/miniconda/$MINICONDA_INSTALLER_SCRIPT
chmod +x $MINICONDA_INSTALLER_SCRIPT
./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX
# Out:
# PREFIX=/usr/local
# installing: python-3.6.5-hc3d631a_2 ...
# installing: ca-certificates-2018.03.07-0 ...
# installing: conda-env-2.6.0-h36134e3_1 ...
# installing: libgcc-ng-7.2.0-hdf63c60_3 ...
# installing: libstdcxx-ng-7.2.0-hdf63c60_3 ...
# installing: libffi-3.2.1-hd88cf55_4 ...
# installing: ncurses-6.1-hf484d3e_0 ...
# installing: openssl-1.0.2o-h20670df_0 ...
# installing: tk-8.6.7-hc745277_3 ...
# installing: xz-5.2.4-h14c3975_4 ...
# installing: yaml-0.1.7-had09818_2 ...
# installing: zlib-1.2.11-ha838bed_2 ...
# installing: libedit-3.1.20170329-h6b74fdf_2 ...
# installing: readline-7.0-ha6073c6_4 ...
# installing: sqlite-3.23.1-he433501_0 ...
# installing: asn1crypto-0.24.0-py36_0 ...
# installing: certifi-2018.4.16-py36_0 ...
# installing: chardet-3.0.4-py36h0f667ec_1 ...
# installing: idna-2.6-py36h82fb2a8_1 ...
# installing: pycosat-0.6.3-py36h0a5515d_0 ...
# installing: pycparser-2.18-py36hf9f622e_1 ...
# installing: pysocks-1.6.8-py36_0 ...
# ...

# %%
# !conda install pytorch torchvision cudatoolkit=10.1 -c pytorch
# Out:
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - cudatoolkit=10.1
#     - pytorch
#     - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     tqdm-4.54.1                |     pyhd3eb1b0_0          54 KB
#     libstdcxx-ng-9.1.0         |       hdf63c60_0         4.0 MB
#     conda-4.9.2                |   py36h06a4308_0         3.1 MB
#     mkl_fft-1.2.0              |   py36h23d657b_0         164 KB
#     cryptography-3.3.1         |   py36h3c74f83_0         638 KB
#     python-3.6.8               |       h0371630_0        34.4 MB
#     conda-package-handling-1.7.2|   py36h03888b9_0         967 KB
#     mkl_random-1.1.1           |   py36h0573a6f_0         382 KB
#     sqlite-3.26.0              |       h7b6447c_0         1.9 MB
#     openssl-1.1.1i             |       h27cfd23_0         3.8 MB
# ...

# %%
# !pip uninstall pymic
# Out:
# Uninstalling PYMIC-0.2:
#   Would remove:
#     /usr/local/bin/pymic_evaluate
#     /usr/local/bin/pymic_net_run
#     /usr/local/lib/python3.6/site-packages/PYMIC-0.2.dist-info/*
#     /usr/local/lib/python3.6/site-packages/pymic/*
# Proceed (y/n)? y
#   Successfully uninstalled PYMIC-0.2

# %%
# !pip install pymic
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/21/2e/4f21e197cf577908271a76b8dda29cad62faa74da31c674c816cbe0ad36d/PYMIC-0.2-py3-none-any.whl
# cryptography 3.3.1 has requirement cffi>=1.12, but you'll have cffi 1.11.5 which is incompatible.
# ...

# %%
# !python "/content/drive/My Drive/Colab Notebooks/coplenet_run.py" train "/content/drive/My Drive/Colab Notebooks/config/config.cfg"
# Out:
# dataset tensor_type float float
# dataset root_dir /content/drive/MyDrive/Colab Notebooks/data /content/drive/MyDrive/Colab Notebooks/data
# dataset train_csv /content/drive/MyDrive/Colab Notebooks/config/image_train.csv /content/drive/MyDrive/Colab Notebooks/config/image_train.csv
# dataset test_csv /content/drive/My Drive/Colab Notebooks/config/data_test1.csv /content/drive/My Drive/Colab Notebooks/config/data_test1.csv
# dataset modal_num 1 1
# dataset train_transform [ChannelWiseNormalize, LabelConvert, RandomCrop, LabelToProbability] ['ChannelWiseNormalize', 'LabelConvert', 'RandomCrop', 'LabelToProbability']
# dataset test_transform [ChannelWiseNormalize] ['ChannelWiseNormalize']
# dataset channelwisenormalize_mean None None
# dataset channelwisenormalize_std None None
# dataset channelwisenormalize_channels [0] [0]
# dataset channelwisenormalize_zero_to_random False False
# dataset channelwisenormalize_inverse False False
# dataset labelconvert_source_list [0, 255] [0, 255]
# ...

# %%
# !python "/content/drive/My Drive/Colab Notebooks/HeadNeck_GTV/coplenet_run.py" train "/content/drive/MyDrive/Colab Notebooks/HeadNeck_GTV/examples/miccai/config/train_test.cfg"
# Out:
# dataset root_dir /content/drive/MyDrive/Colab Notebooks/HeadNeck_GTV/dataroot/origindata /content/drive/MyDrive/Colab Notebooks/HeadNeck_GTV/dataroot/origindata
# dataset train_csv /content/drive/MyDrive/Colab Notebooks/HeadNeck_GTV/examples/miccai/config/image_train.csv /content/drive/MyDrive/Colab Notebooks/HeadNeck_GTV/examples/miccai/config/image_train.csv
# dataset valid_csv /content/drive/MyDrive/Colab Notebooks/HeadNeck_GTV/examples/miccai/config/image_train.csv /content/drive/MyDrive/Colab Notebooks/HeadNeck_GTV/examples/miccai/config/image_train.csv
# dataset test_csv /content/drive/MyDrive/Colab Notebooks/HeadNeck_GTV/examples/miccai/config/image_train.csv /content/drive/MyDrive/Colab Notebooks/HeadNeck_GTV/examples/miccai/config/image_train.csv
# dataset modal_num 1 1
# dataset train_transform [RandomCrop, RandomFlip] ['RandomCrop', 'RandomFlip']
# dataset valid_transform [Donothing] ['Donothing']
# dataset test_transform [Donothing] ['Donothing']
# ...
