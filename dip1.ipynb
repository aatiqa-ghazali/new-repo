# %% [markdown]
# <a href="https://colab.research.google.com/github/aatiqa-ghazali/new-repo/blob/master/dip1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# %cd drive/My\ Drive/Colab\ Notebooks/
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/Colab Notebooks

# %%
import os , glob
import nibabel as nib
import numpy as np 
import matplotlib.pyplot as plt
import cv2
from google.colab.patches import cv2_imshow

# %%
##loading image
image=cv2.imread('/content/drive/MyDrive/Colab Notebooks/Colab Notebooks/images/flower.png') 
##display image
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=786x1180 at 0x7F269F48A210>

# %%
##conversion in greyscale

# %%
image1=cv2.imread('/content/drive/MyDrive/Colab Notebooks/Colab Notebooks/images/flower.png',cv2.IMREAD_GRAYSCALE)
cv2_imshow(image1)
# Out:
# <PIL.Image.Image image mode=L size=786x1180 at 0x7F26994D3DD0>

# %%
(thresh, blackAndWhiteImage) = cv2.threshold(image1, 127, 255, cv2.THRESH_BINARY)
cv2_imshow(blackAndWhiteImage)
# Out:
# <PIL.Image.Image image mode=L size=786x1180 at 0x7F26994C9A50>
